# %%
# This loads numerous packages and defines functions I used in these notes

# %run -i "controls_imports.py"

# %% [markdown]
# Works by doing partial fraction expansion first then performing the inverse Laplace transform on each term one at a time.

# %%
ctrl_ilt(6*(s+50)/(s**2+40*s+300))
# Out:
# Expanded this is  [-6/(s + 30), 12/(s + 10)]
# Terms are  -6/(s + 30)
# -6*exp(-30*t)
# Terms are  12/(s + 10)
# 12*exp(-10*t)
#     -10⋅t      -30⋅t
# 12⋅ℯ      - 6⋅ℯ

# %% [markdown]
# Doesn't work

# %%
ctrl_ilt(6*(s+50)/(s**2+4*s+300))
# Out:
# Expanded this is  [6*(s + 50)/(s**2 + 4*s + 300)]
# Terms are  6*(s + 50)/(s**2 + 4*s + 300)
# (72*sqrt(74)*sin(2*sqrt(74)*t) + 222*cos(2*sqrt(74)*t))*exp(-2*t)/37
#                                           -2⋅t
# (72⋅√74⋅sin(2⋅√74⋅t) + 222⋅cos(2⋅√74⋅t))⋅ℯ
# ──────────────────────────────────────────────
#                       37

# %%
sym.inverse_laplace_transform(6*(s+50)/(s**2+4*s+300),s, t)
# Out:
#                                           -2⋅t
# (72⋅√74⋅sin(2⋅√74⋅t) + 222⋅cos(2⋅√74⋅t))⋅ℯ
# ──────────────────────────────────────────────
#                       37

# %% [markdown]
# Doesn't work. Mine works better.

# %%
sym.inverse_laplace_transform(6*(s+50)/(s**2+40*s+300), s, t)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documents/GitHub/Tennessee_Tech_ECE_3210/controls_imports.py in <module>
# ----> 1 sym.inverse_laplace_transform(6*(s+50)/(s**2+40*s+300), s, t)
#
# ~/opt/anaconda3/envs/latest/lib/python3.8/site-packages/sympy/integrals/transforms.py in inverse_laplace_transform(F, s, t, plane, **hints)
#    1291     if isinstance(F, MatrixBase) and hasattr(F, 'applyfunc'):
#    1292         return F.applyfunc(lambda Fij: inverse_laplace_transform(Fij, s, t, plane, **hints))
# -> 1293     return InverseLaplaceTransform(F, s, t, plane).doit(**hints)
#    1294
#    1295
#
# ~/opt/anaconda3/envs/latest/lib/python3.8/site-packages/sympy/integrals/transforms.py in doit(self, **hints)
#     118         if try_directly:
#     119             try:
# --> 120                 return self._compute_transform(self.function,
# ...
